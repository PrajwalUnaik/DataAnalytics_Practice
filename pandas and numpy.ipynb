# %% [markdown]
# <a href="https://colab.research.google.com/github/PrajwalUnaik/DataAnalytics_Practice/blob/main/pandas%20and%20numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.empty(3)

# %%
type(a[0])
# Out:
# numpy.float64

# %%
a
# Out:
# array([1., 1., 1.])

# %%
a.shape = (3,1)

# %%
a
# Out:
# array([[1.],
#        [1.],
#        [1.]])

# %%
b = np.empty(6)
b
# Out:
# array([4.9e-324, 9.9e-324, 1.5e-323, 9.9e-324, 1.5e-323, 2.0e-323])

# %%
c = np.linspace(2,10,6)
c
# Out:
# array([ 2. ,  3.6,  5.2,  6.8,  8.4, 10. ])

# %%
d = np.array([10,20])
d
# Out:
# array([10, 20])

# %%
a_list = [1,2,3]
d = np.array([a_list])
d
# Out:
# array([[1, 2, 3]])

# %%
type(d)
# Out:
# numpy.ndarray

# %%
e_list = [[1,2,3], [2,3,4]]
e_list
# Out:
# [[1, 2, 3], [2, 3, 4]]

# %%
e = np.array([e_list])

# %%
e.shape
# Out:
# (1, 2, 3)

# %% [markdown]
# help popup

# %%
# ?e.shape

# %%
e
# Out:
# array([[[1, 2, 3],
#         [2, 3, 4]]])

# %%
np.random.seed()

# %%
f = np.random.randint(2,10,size=7)

# %%
f
# Out:
# array([5, 6, 9, 2, 9, 3, 8])

# %%
f[0]
# Out:
# 5

# %%
f[0:3]
# Out:
# array([5, 6, 9])

# %%
f[-1]
# Out:
# 8

# %%
from skimage import io
photo = io.imread('Candidate.png')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (831, 1068, 4)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[100:350,50:280])

# %%
plt.imshow(photo[::2,::2])

# %%
photo
# Out:
# array([[[253, 161,  81, 255],
#         [253, 161,  81, 255],
#         [253, 161,  81, 255],
#         ...,
#         [253, 161,  81, 255],
#         [253, 161,  81, 255],
#         [253, 161,  81, 255]],
#
#        [[254, 185, 124, 255],
#         [255, 200, 146, 255],
#         [255, 199, 145, 255],
#         ...,
#         [253, 199, 145, 255],
#         [253, 199, 145, 255],
#         [253, 199, 145, 255]],
#
#        [[255, 187, 126, 255],
#         [252, 139,   0, 255],
#         [252, 149,  51, 255],
#         ...,
#         [253, 149,  51, 255],
#         [253, 149,  51, 255],
#         [253, 149,  51, 255]],
#
#        ...,
#
#        [[254, 190, 134, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[254, 190, 134, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
photo_sin = np.sin(photo)
photo_sin
# Out:
# array([[[ 0.9946, -0.7026, -0.63  , -0.5063],
#         [ 0.9946, -0.7026, -0.63  , -0.5063],
#         [ 0.9946, -0.7026, -0.63  , -0.5063],
#         ...,
#         [ 0.9946, -0.7026, -0.63  , -0.5063],
#         [ 0.9946, -0.7026, -0.63  , -0.5063],
#         [ 0.9946, -0.7026, -0.63  , -0.5063]],
#
#        [[ 0.452 ,  0.3467, -0.9956, -0.5063],
#         [-0.5063, -0.8735,  0.9966, -0.5063],
#         [-0.5063, -0.882 ,  0.4678, -0.5063],
#         ...,
#         [ 0.9946, -0.882 ,  0.4678, -0.5063],
#         [ 0.9946, -0.882 ,  0.4678, -0.5063],
#         [ 0.9946, -0.882 ,  0.4678, -0.5063]],
#
#        [[-0.5063, -0.997 ,  0.33  , -0.5063],
#         [ 0.623 ,  0.6963,  0.    , -0.5063],
#         [ 0.623 , -0.9746,  0.6704, -0.5063],
#         ...,
#         [ 0.9946, -0.9746,  0.6704, -0.5063],
#         [ 0.9946, -0.9746,  0.6704, -0.5063],
#         [ 0.9946, -0.9746,  0.6704, -0.5063]],
#
#        ...,
#
#        [[ 0.452 ,  0.9976,  0.8857, -0.5063],
# ...

# %%
print(np.sum(photo))
# Out:
# 823896587

# %%
print(np.max(photo))
# Out:
# 255

# %%
print(np.min(photo))
# Out:
# 0

# %%
print(np.mean(photo))
# Out:
# 232.08145363196726

# %%
print(np.std(photo))
# Out:
# 56.10370476984381

# %%
print(np.median(photo))
# Out:
# 255.0

# %%
print(np.var(photo))
# Out:
# 3147.625688901795

# %%
print(np.argmin(photo))
# Out:
# 8550

# %%
print(np.argmax(photo))
# Out:
# 3

# %%
p = np.array([1,2,3,4,5])

# %%
p < 3
# Out:
# array([ True,  True, False, False, False])

# %%
p > 3
# Out:
# array([False, False, False,  True,  True])

# %%
p[p>3]
# Out:
# array([4, 5])

# %%
p[p<=3]
# Out:
# array([1, 2, 3])

# %%
p[p<3]
# Out:
# array([1, 2])

# %%
photo_masked = np.where(photo>100, 255, 0)

# %%
plt.imshow(photo_masked)

# %%
a_array = np.array([99,2,3])
b_array = np.array([4,5,6])

# %%
a_array + b_array
# Out:
# array([103,   7,   9])

# %%
a_array * b_array
# Out:
# array([396,  10,  18])

# %%
a_array * 10
# Out:
# array([990,  20,  30])

# %%
a_array @ b_array
# Out:
# 424

# %%
a_array.dot(b_array)
# Out:
# 424

# %%
sum(a_array)
# Out:
# 104

# %%
sum(b_array)
# Out:
# 15

# %%
sum(a_array * b_array)
# Out:
# 424

# %%
a_array*b_array
# Out:
# array([396,  10,  18])

# %%
plt.imshow(photo[:,:,0].T)

# %%
x = np.array([123,456,789])
y = np.array([321,654,987)

# %%
z = np.random.randint(1,10,size = 7)

# %%
z
# Out:
# array([4, 6, 6, 9, 2, 8, 2])

# %%
np.sort(z)
# Out:
# array([2, 2, 4, 6, 6, 8, 9])

# %% [markdown]
# # Pandas

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ronecone/hotel-booking-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.79k/2.79k [00:00<00:00, 698kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/ronecone/hotel-booking-data/versions/1

# %%
import pandas as pd
import numpy as np

# %%
file_path = "/root/.cache/kagglehub/datasets/ronecone/hotel-booking-data/versions/1/hotel-booking-data.txt"
df = pd.read_csv(file_path, delimiter='\t')
print(df.head())
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %%
df['Company'].value_counts()
# Out:
# Company
# Leexo           3
# Fivechat        3
# Quinu           3
# Jabbersphere    2
# Twitterlist     2
#                ..
# Topiclounge     1
# Shufflebeat     1
# Skyvu           1
# Youspan         1
# Twitterworks    1
# Name: count, Length: 114, dtype: int64

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]
